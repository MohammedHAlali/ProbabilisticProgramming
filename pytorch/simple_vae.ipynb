# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 10.0)
plt.rcParams['figure.dpi'] = 80

# %%
plot_prediction()

# %%
plot_elbo_density()

# %%
plot_logpdf_Gaussian()

# %%
plot_generative()
