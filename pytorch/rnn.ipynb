# %%
plt.figure('data')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure('sim')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure('state-loss')
# Out:
# <img src="data:image/png;base64,..." width="640">
